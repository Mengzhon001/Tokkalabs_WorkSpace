# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Generate some random data
data = pd.read_csv('/Users/andyma/Desktop/Python /Tokkalabs_WorkSpace/EigenPhi_data/Sandwich_profitMargin.csv', index_col=0)

data = data[~(data['Profit_margin']<-2) ]
plt.figure(figsize=(15, 4),dpi=300)
# Plotting the histogram
plt.hist(data['Profit_margin'], bins=1000, edgecolor='black')
plt.title('Histogram of Random Data')
plt.xlabel('Value')
plt.ylabel('Frequency')
# plt.grid(True)
plt.savefig('/Users/andyma/Desktop/Python /Tokkalabs_WorkSpace/EigenPhi_data/Sandwich_profitMargin_polt.png')
plt.show()

# %%
quantiles = data['Profit_margin'].quantile([0.5, 0.75, 0.9, 0.95])

print("Quantiles:")
print(quantiles)
# Out:
# Quantiles:
# 0.50    0.664336
# 0.75    0.882353
# 0.90    0.964203
# 0.95    0.983035
# Name: Profit_margin, dtype: float64
